# %% [markdown]
# <style>
# /* 全局深色适配样式 */
# *{box-sizing:border-box;}
# .banner{
#     width:100%;
#     height:220px;
#     background:#121214;
#     border-radius:14px;
#     position:relative;
#     overflow:hidden;
#     margin-bottom:32px;
#     border:1px solid #28282c;
# }
# .banner-content{
#     position:absolute;
#     left:40px;
#     top:50%;
#     transform: translateY(-50%);
# }
# .banner h1{
#     color:#ffffff;
#     font-size:46px;
#     margin:0;
#     font-weight:700;
#     letter-spacing:1px;
# }
# .banner p{
#     color:#d0d0d8;
#     font-size:20px;
#     margin:8px 0 0;
# }
# /* 作品卡片通用样式 */
# .card-wrap{
#     margin-bottom:30px;
# }
# .card-title{
#     color:#eee;
#     font-size:22px;
#     margin:0 0 12px;
#     display:flex;
#     align-items:center;
#     gap:8px;
# }
# .card-mind{
#     background:#1c1c21;
#     border-radius:12px;
#     padding:24px 28px;
#     border-left:5px solid #3b82f6;
#     border:1px solid #2c2c32;
# }
# .card-proto{
#     background:#1c1c21;
#     border-radius:12px;
#     padding:24px 28px;
#     border-left:5px solid #10b981;
#     border:1px solid #2c2c32;
# }
# .item-list{
#     line-height:2.1;
#     font-size:15px;
# }
# .item-list a{
#     color:#74b9ff;
#     text-decoration:none;
# }
# .card-proto .item-list a{
#     color:#4ade80;
# }
# .bottom-tip{
#     text-align:center;
#     color:#797988;
#     font-size:14px;
#     margin-top:40px;
# }
# </style>
#
# <!-- 顶部首屏Banner -->
# <div class="banner">
#     <div class="banner-content">
#         <h1>Hello，Welcome to my portfolio</h1>
#         <h2>欢迎观看我的作品集</h2>
#     </div>
# </div>
#
# <div id="work">
#     <!-- 思维导图模块 -->
#     <div class="card-wrap">
#         <div class="card-title">🧠 思维导图系列</div>
#         <div class="card-mind item-list">
# 1. <a href="https://app.xmind.cn/share/WJC2AvKe" target="_blank">【Xmind思维导图】小组学习陪伴桌宠系统</a><br>
# 2. <a href="https://app.xmind.cn/share/xCOfNQaM" target="_blank">【Xmind思维导图】智学宠伴——多模态大数据 Vue、Web 开发赋能中小学生智能学习养成平台</a><br>
# 3. <a href="https://app.xmind.cn/share/A67LFfM9" target="_blank">【Xmind思维导图】产品开发全流程思维导图</a><br>
# 4. <a href="https://app.xmind.cn/share/vtjgfJUv" target="_blank">【Xmind思维导图】抖音的诞生与发展逻辑图</a><br>
# 5. <a href="https://app.xmind.cn/share/0nvBZRew" target="_blank">【Xmind思维导图】抖音功能结构图</a><br>
# 6. <a href="https://app.xmind.cn/share/V9c3yLxJ" target="_blank">【Xmind思维导图】抖音信息架构图</a>
#   </div>
# </div>
#
# <div id="work">
#     <!-- 思维导图模块 -->
#     <div class="card-wrap">
#         <div class="card-title">❤️ 流程图系列</div>
#         <div class="card-mind item-list">
# 1. <a href="https://www.processon.com/view/link/6a226fe76a271336cb964366" target="_blank">登录流程图</a><br>
# 2. <a href="https://www.processon.com/view/link/6a226fb48810e7537608e463">上传视频流程图</a><br>
# 3. <a href="https://www.processon.com/view/link/6a226c041c90830c1127b0f1" target="_blank">发布视频流程图</a><br>
#     </div>
# </div>
# <div id="work">
#     <!-- 思维导图模块 -->
#     <div class="card-wrap">
#         <div class="card-title">🎨 高保真原型图系列</div>
#         <div class="card-mind item-list">
# 1. <a href="https://modao.cc/proto/y41BfKPotfyf9qsFKpLVS/sharing?view_mode=read_only"target="_blank">【墨刀】#抖音仿真设计</a><br>
# 2. <a href="https://modao.cc/proto/nkpsqEiztfybxeLMYijP4L/sharing?view_mode=read_only“target="_blank”>【墨刀】#基础登录交互页面</a><br>
# 3. <a href="https://modao.cc/design/share/moaGXYDtg5hstgwWplFY" target="_blank">【墨刀】#second life小程序</a>
#         </div>
#     </div>
# </div>
#
# <div class="bottom-tip">项目作品集｜产品原型 + 项目架构思维导图 · 持续迭代更新</div>
